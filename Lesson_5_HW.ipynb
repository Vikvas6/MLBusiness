# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Прочитайте базу my_BRENT2019.csv и перейдите к представлению ряда первыми разностями

# %%
df = pd.read_csv('my_BRENT2019.csv' ,sep = ',', index_col=[0], parse_dates=[0])
df.head()
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday
# Дата
# 2010-09-01          2           0                0                0
# 2010-09-02          3           0                0                0
# 2010-09-03          4           0                0                0
# 2010-09-04          5           0                0                0
# 2010-09-05          6           0                1                0

# %%
df_diff = df['Значение'].values[1:] - df['Значение'].values[:-1]
df['diffs'] = 0.0
df['diffs'].values[1:] = df_diff

# %%
# Удалим признаки так же, как в прошлом ДЗ
df = df.drop(columns=['dayofmonth', 'dayofyear', 'dayofweek', 'month', 'is_prev_holiday', 'is_next_holiday',
                     #    'year', 'quarter', 'weekofyear', 'is_holiday', 'Значение'
                     ])
df.head()
# Out:
#             Значение  year  quarter  weekofyear  is_holiday  diffs
# Дата
# 2010-09-01     76.37  2010        3          35           0   0.00
# 2010-09-02     76.89  2010        3          35           0   0.52
# 2010-09-03     76.57  2010        3          35           0  -0.32
# 2010-09-04     76.62  2010        3          35           0   0.05
# 2010-09-05     76.63  2010        3          35           0   0.01

# %%
plt.figure( figsize=( 15, 7 ))
plt.ylabel('Brent price, USD')
plt.plot(df.index.get_level_values('Дата'),df['diffs'], '.')
plt.title( 'Первые разности' )
plt.show()

# %% [markdown]
# ### 2. Добавьте первые разности по стоимости доллара и евро к рублю

# %%
rub_doll=pd.read_excel('RC_F01_09_2010_T01_09_2019.xlsx')
rub_doll.index = pd.to_datetime(rub_doll['data'].values).date
rub_doll.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_doll_diff = rub_doll['curs'].values[1:] - rub_doll['curs'].values[:-1]
rub_doll['diffs'] = 0.0
rub_doll['diffs'].values[1:] = rub_doll_diff
rub_doll.head()
# Out:
#                curs   diffs
# 2010-09-01  30.8669  0.0000
# 2010-09-02  30.8001 -0.0668
# 2010-09-03  30.6858 -0.1143
# 2010-09-04  30.6922  0.0064
# 2010-09-07  30.5771 -0.1151

# %%
rub_e=pd.read_excel('R_E01_09_2010_T01_09_2019.xlsx')
rub_e.index = pd.to_datetime(rub_e['data'].values)
rub_e.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_e_diff = rub_e['curs'].values[1:] - rub_e['curs'].values[:-1]
rub_e['diffs'] = 0.0
rub_e['diffs'].values[1:] = rub_e_diff
rub_e.head()
# Out:
#                curs   diffs
# 2010-09-01  39.0127  0.0000
# 2010-09-02  39.1654  0.1527
# 2010-09-03  39.2901  0.1247
# 2010-09-04  39.3505  0.0604
# 2010-09-07  39.4720  0.1215

# %%
df.loc[df.index, 'rub_doll'] = rub_doll.loc[df.index, 'diffs']
df.loc[df.index, 'rub_e'] = rub_e.loc[df.index, 'diffs']
df['rub_doll'] = df['rub_doll'].fillna(0.0)
df['rub_e'] = df['rub_e'].fillna(0.0)
df.head()
# Out:
# C:\Users\viktor.vashchenkov\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
#             Значение  year  quarter  weekofyear  is_holiday  diffs  rub_doll  \
# Дата
# 2010-09-01     76.37  2010        3          35           0   0.00    0.0000
# 2010-09-02     76.89  2010        3          35           0   0.52   -0.0668
# 2010-09-03     76.57  2010        3          35           0  -0.32   -0.1143
# 2010-09-04     76.62  2010        3          35           0   0.05    0.0064
# 2010-09-05     76.63  2010        3          35           0   0.01    0.0000
#
#              rub_e
# Дата
# 2010-09-01  0.0000
# 2010-09-02  0.1527
# 2010-09-03  0.1247
# 2010-09-04  0.0604
# 2010-09-05  0.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2667 entries, 2010-09-01 to 2019-09-01
# Data columns (total 8 columns):
# Значение      2667 non-null float64
# year          2667 non-null int64
# quarter       2667 non-null int64
# weekofyear    2667 non-null int64
# is_holiday    2667 non-null int64
# diffs         2667 non-null float64
# rub_doll      2667 non-null float64
# rub_e         2667 non-null float64
# dtypes: float64(4), int64(4)
# memory usage: 267.5 KB

# %% [markdown]
# ### 3. сделайте ее перрасчет (ресемплинг) в представление по неделям.

# %%
df_w = df.resample("W").apply('mean')

# %%
np.where(np.isnan(df_w))
# Out:
# (array([58, 58, 58, 58, 58, 58, 58, 58], dtype=int64),
#  array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int64))

# %%
df_w.iloc[58] = df_w.iloc[57]

# %%
df_w_start = df_w['Значение'].values[0]
df_w_cn = df_w.copy()
df_w = df_w.drop(columns=['Значение'])
df_w.head()
# Out:
#               year   quarter  weekofyear  is_holiday     diffs  rub_doll  \
# Дата
# 2010-09-05  2010.0  3.000000        35.0    0.000000  0.052000 -0.034940
# 2010-09-12  2010.0  3.000000        36.0    0.166667  0.288333  0.033583
# 2010-09-19  2010.0  3.000000        37.0    0.000000 -0.021667  0.021433
# 2010-09-26  2010.0  3.000000        38.0    0.000000  0.118333 -0.013250
# 2010-10-03  2010.0  3.333333        39.0    0.000000  0.791667 -0.072567
#
#                rub_e
# Дата
# 2010-09-05  0.067560
# 2010-09-12 -0.026467
# 2010-09-19  0.187483
# 2010-09-26  0.121083
# 2010-10-03  0.029883

# %% [markdown]
# ### 4. Постройте модель предсказания 1-й точки от текущей (h=1).

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
def split_data_b( data, split_date ):
    return data.loc[data.index.get_level_values('Дата') <= split_date].copy(), \
           data.loc[data.index.get_level_values('Дата') >  split_date].copy()
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
date_for_split = '01-01-2018'

train, test = split_data_b( df_w, date_for_split)
plt.figure( figsize=( 15, 7 ))
plt.ylabel('Brent price, USD')
plt.plot(train.index.get_level_values('Дата'),train['diffs'], '.', label='train data' )
plt.plot(test.index.get_level_values('Дата'),test['diffs'], '.', label='test data', color='r')
plt.title( 'Тестовые и тренировочные данные' )
plt.legend()
plt.show()

# %%
h = 1
X_train_1 = train.iloc[:-h,:]
y_train_1 = train['diffs'].values[h:]
X_test_1 = test.iloc[:-h,:]
y_test_1 = test['diffs'].values[h:]

model_gb_1 = GradientBoostingRegressor(max_depth=8, random_state=0, n_estimators=45)
model_gb_1.fit( X_train_1, y_train_1 ) 
X_test_pred_gb_1 = model_gb_1.predict(X_test_1)
plt.figure( figsize=( 20, 4 ))

plt.ylabel('Brent price, USD')
plt.plot(test.index[h:],X_test_pred_gb_1, label='predicted data', color='b' )
plt.plot(test.index[h:],y_test_1, label='test data', color='r')

plt.legend()
plt.show()

er_g = mean_absolute_percentage_error(y_true=y_test_1, y_pred=X_test_pred_gb_1)

print('ошибка градиентного бустинга :  ', er_g, '%')
# Out:
# ошибка градиентного бустинга :   159.16982184702627 %

# %% [markdown]
# #### Прямое прогнозирование

# %%
train, test = split_data_b( df_w_cn, date_for_split)

h = 1
X_train_1 = train.iloc[:-h,:]
y_train_1 = train['Значение'].values[h:]
X_test_1 = test.iloc[:-h,:]
y_test_1 = test['Значение'].values[h:]

model_gb_1 = GradientBoostingRegressor(max_depth=8, random_state=0, n_estimators=45)
model_gb_1.fit( X_train_1, y_train_1 ) 
X_test_pred_gb_1 = model_gb_1.predict(X_test_1)
plt.figure( figsize=( 20, 4 ))

plt.ylabel('Brent price, USD')
plt.plot(test.index[h:],X_test_pred_gb_1, label='predicted data', color='b' )
plt.plot(test.index[h:],y_test_1, label='test data', color='r')

plt.legend()
plt.show()

er_g = mean_absolute_percentage_error(y_true=y_test_1, y_pred=X_test_pred_gb_1)

print('ошибка градиентного бустинга :  ', er_g, '%')
# Out:
# ошибка градиентного бустинга :   3.5933055677317567 %

# %% [markdown]
# ### 5. Сделайте вывод о поведении ошибки предсказания ряда в сравнении с прямым прогнозированием.

# %% [markdown]
# Ошибка по первым разностям на 2 порядка отличается от ошибки прямого прогнозирования и составила более 150%, иными словами по первым разностям я не смог ничего предсказать.
